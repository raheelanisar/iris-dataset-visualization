# %% [markdown]
# # 🌸 Iris Dataset Visualization
# ### DevelopersHub Corporation — AI/ML Engineering Internship
# **Intern Name:** Raheela  Nisar
# **Project:** Task 1 - Exploring and Visualizing the Iris Dataset
# **Organization:** DevelopersHub Corporation

# %%
pip install sweetviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

# %%
# Fetching the dataset
df = pd.read_csv(r'C:\Windows\Code\IRS\iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Fetching the dataset
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Head of dataset
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Shape of dataset
df.shape
# Out:
# (150, 6)

# %%
# 3 types of Species
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Species'] = encoder.fit_transform(df['Species'])

# %%
df.Species.unique()
#Iris-setosa = 0, Iris-versicolor = 1, Iris-virginica = 2
# Out:
# array([0, 1, 2])

# %%
report=sv.analyze(source=df)
report.show_html('Iris Report')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 report=sv.analyze(source=df)
#       2 report.show_html('Iris Report')
#
# NameError: name 'sv' is not defined

# %%
df.isnull().sum()

# %%
print(df.columns)

# %%
plt.figure(figsize=(10,4))
plt.title('Comparison between sepal width and length on the basis of species')
sns.scatterplot(data=df, x='SepalLengthCm', y='SepalWidthCm', hue='Species', palette='deep')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.title('Comparison between petal width and length')
sns.scatterplot(data=df, x='PetalLengthCm', y='PetalWidthCm', hue='Species', palette='deep')
plt.show()

# %%
#correlation between features
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='viridis')

# %%
#Pairplot of Species
sns.pairplot(df,hue="Species",height=3,palette='deep')

# %%
#Seperate Dependent and Independent Features

#For Dependent feature we use 'y' variable
y=df['Species']

#For Indenpendent feature we use 'X' variable
x=df.drop(['Id','Species'],axis=1)

# %%
x.shape,y.shape

# %%
#Spliting into training and testing dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test =  train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier= RandomForestClassifier()

# %%
classifier.fit(x_train,y_train)

# %%
# Feature Importance
classifier.feature_importances_

# %%
for feature, index in zip(x, range(4)):
    print(feature,':',classifier.feature_importances_[index])

# %%
y_pred=classifier.predict(x_test)

# %%
y_pred

# %%
y_actual=np.array(y_test)
y_actual

# %%
print(np.round(classifier.score(x_test,y_test)*100,2),'%')

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_matrix(y_actual,y_pred)

# %%
print(classification_report(y_actual,y_pred))

# %% [markdown]
# ## Key Insights
# - Setosa species is easily separable from other species
# - Petal Length and Petal Width are the most important features
# - Model Accuracy: 97.78%
# - No missing values found in dataset
#
# ## Conclusion
# This project successfully visualized the Iris dataset using
# scatter plots, histograms, and pair plots. Random Forest
# Classifier achieved 97.78% accuracy.

# %%
import os
import joblib

folder = r"D:\Iris_Streamlit_App"

os.makedirs(folder, exist_ok=True)

joblib.dump(model, os.path.join(folder, "model.pkl"))
joblib.dump(scaler, os.path.join(folder, "scaler.pkl"))

print("Files Saved Successfully")
# Out:
# Files Saved Successfully
